# %%
# !pip -q install matplotlib
# !pip -q install pandas 
# !pip -q install numpy

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# /tmp/ipykernel_75834/347984750.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
filename = "Guy_Baz/Sec-117-Public-Records-Complete-Oct-13-2023.xlsx"

# %%
df = pd.read_excel(filename, header=1) # , nrows=10

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          OPEID                             School Name State Transaction Type  \
# 0       103600                      Samford University    AL             Gift
# 1       108100                Arizona State University    AZ             Gift
# 2       108100                Arizona State University    AZ             Gift
# 3       115400          San Francisco State University    CA             Gift
# 4       130500                     Stanford University    CA             Gift
# ...        ...                                     ...   ...              ...
# 96044  4279700     Albert Einstein College of Medicine    NY         Contract
# 96045  4279700     Albert Einstein College of Medicine    NY             Gift
# 96046  4282800     Glasgow Caledonian New York College    NY         Contract
# 96047  4293300  Hackensack Meridian School of Medicine    NJ         Contract
# 96048  4293300  Hackensack Meridian School of Medicine    NJ         Contract
#
# ...

# %%
df.columns
# Out:
# Index(['OPEID', 'School Name', 'State', 'Transaction Type',
#        'Foreign Government Source', 'Attribution Country', 'Amount',
#        'Receipt Date', 'Contract Start Date', 'Contract End date',
#        'Restricted Transaction Foreign Government Legal Name',
#        'Restricted Transaction Foreign Government Legal Name2',
#        'Restricted Transaction Description',
#        'Institution Owned By Foreign Source', 'Foreign Source Owner Name',
#        'Foreign Source Ownership Date', 'Changes Due To Foreign Source Owner',
#        'Legacy Data'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OPEID                                                      int64
# School Name                                               object
# State                                                     object
# Transaction Type                                          object
# Foreign Government Source                                 object
# Attribution Country                                       object
# Amount                                                   float64
# Receipt Date                                             float64
# Contract Start Date                                      float64
# Contract End date                                        float64
# Restricted Transaction Foreign Government Legal Name      object
# Restricted Transaction Foreign Government Legal Name2     object
# Restricted Transaction Description                        object
# Institution Owned By Foreign Source                       object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96049, step=1)

# %%
df.values
# Out:
# array([[103600, 'Samford University', 'AL', ..., nan, nan, 'No'],
#        [108100, 'Arizona State University', 'AZ', ..., nan, nan, 'No'],
#        [108100, 'Arizona State University', 'AZ', ..., nan, nan, 'No'],
#        ...,
#        [4282800, 'Glasgow Caledonian New York College', 'NY', ..., nan,
#         nan, 'Yes'],
#        [4293300, 'Hackensack Meridian School of Medicine', 'NJ', ...,
#         nan, nan, 'Yes'],
#        [4293300, 'Hackensack Meridian School of Medicine', 'NJ', ...,
#         nan, nan, 'Yes']], dtype=object)

# %%
df.head(7)
# Out:
#     OPEID                     School Name State Transaction Type  \
# 0  103600              Samford University    AL             Gift
# 1  108100        Arizona State University    AZ             Gift
# 2  108100        Arizona State University    AZ             Gift
# 3  115400  San Francisco State University    CA             Gift
# 4  130500             Stanford University    CA             Gift
# 5  130500             Stanford University    CA             Gift
# 6  130500             Stanford University    CA             Gift
#
#   Foreign Government Source Attribution Country      Amount  Receipt Date  \
# 0                        No              CANADA    500000.0       45079.0
# 1                        No           INDONESIA    250000.0       45002.0
# 2                        No           INDONESIA    250000.0       45002.0
# 3                       Yes              KUWAIT     73316.0       45044.0
# 4                        No           SINGAPORE  10000000.0       44951.0
# ...

# %%
df.tail(13)
# Out:
#          OPEID                                        School Name State  \
# 96036  4250600        California Institute of Advanced Management    CA
# 96037  4250600        California Institute of Advanced Management    CA
# 96038  4277100  Young Americans College of the Performing Arts...    CA
# 96039  4277100  Young Americans College of the Performing Arts...    CA
# 96040  4279700                Albert Einstein College of Medicine    NY
# 96041  4279700                Albert Einstein College of Medicine    NY
# 96042  4279700                Albert Einstein College of Medicine    NY
# 96043  4279700                Albert Einstein College of Medicine    NY
# 96044  4279700                Albert Einstein College of Medicine    NY
# 96045  4279700                Albert Einstein College of Medicine    NY
# 96046  4282800                Glasgow Caledonian New York College    NY
# 96047  4293300             Hackensack Meridian School of Medicine    NJ
# ...

# %%
states_series = df["State"]

# %%
type(states_series)
# Out:
# pandas.core.series.Series

# %%
states_series
# Out:
# 0        AL
# 1        AZ
# 2        AZ
# 3        CA
# 4        CA
#          ..
# 96044    NY
# 96045    NY
# 96046    NY
# 96047    NJ
# 96048    NJ
# Name: State, Length: 96049, dtype: object

# %%
states_df = df[["State"]]

# %%
type(states_df)
# Out:
# pandas.core.frame.DataFrame

# %%
states_df
# Out:
#       State
# 0        AL
# 1        AZ
# 2        AZ
# 3        CA
# 4        CA
# ...     ...
# 96044    NY
# 96045    NY
# 96046    NY
# 96047    NJ
# 96048    NJ
#
# [96049 rows x 1 columns]

# %%
table = df[["State", "Amount"]]

# %%
table
# Out:
#       State      Amount
# 0        AL    500000.0
# 1        AZ    250000.0
# 2        AZ    250000.0
# 3        CA     73316.0
# 4        CA  10000000.0
# ...     ...         ...
# 96044    NY    737375.0
# 96045    NY   1024469.0
# 96046    NY  21800000.0
# 96047    NJ         0.0
# 96048    NJ         0.0
#
# [96049 rows x 2 columns]

# %%
df.describe()
# Out:
#               OPEID        Amount  Receipt Date  Contract Start Date  \
# count  9.604900e+04  9.604700e+04  59771.000000         65338.000000
# mean   2.670105e+05  5.333411e+05  42184.104934         42669.237197
# std    3.250270e+05  4.037216e+06   1860.343955          2741.513382
# min    1.009000e+05 -5.377700e+05  29601.000000         19294.000000
# 25%    1.315000e+05  5.500000e+03  41100.000000         41640.000000
# 50%    2.077000e+05  6.516200e+04  42459.000000         43101.000000
# 75%    3.210000e+05  3.367515e+05  43566.000000         44124.000000
# max    4.293300e+06  4.308510e+08  54642.000000        412906.000000
#
#        Contract End date  Foreign Source Ownership Date
# count       6.414300e+04                           4.00
# mean        4.659742e+04                       40426.25
# std         8.034654e+04                        2302.50
# min         4.000000e+00                       39275.00
# 25%         4.257100e+04                       39275.00
# ...
